# %% [markdown]
# # Ethiopia Climate Trend Analysis (2015-2026)
#
# This notebook focuses on profiling, cleaning, and exploring the climate dataset for Ethiopia to extract meaningful insights for the COP32 position paper.
